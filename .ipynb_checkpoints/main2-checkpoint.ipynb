# %% [markdown]
# Sources of help:
# https://stackoverflow.com/questions/12477823/calling-a-function-in-a-separate-file-in-python
# https://stackoverflow.com/questions/20186344/ipynb-import-another-ipynb-file
#
# https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.html
# https://stackoverflow.com/questions/19482970/get-list-from-pandas-dataframe-column-headers
# https://stackoverflow.com/questions/19379120/how-to-read-a-config-file-using-python
# https://stackoverflow.com/questions/12943819/how-to-prettyprint-a-json-file
# https://stackoverflow.com/questions/42370977/how-to-save-a-new-sheet-in-an-existing-excel-file-using-pandas

# %%
#data science stuff
import numpy as np
import pandas as pd
import pprint
import configparser
config = configparser.ConfigParser()
config.read('config.INI')
import time

#from ipynb.fs.full.readMaps import *
#import ipynb.fs.full.readMaps
# %run readMaps.ipynb
# %run readMPLinks.ipynb
# %run readTeams.ipynb
# %run createLeaderboard.ipynb
# %run osuApiRequests.ipynb
# %run processMP.ipynb
# %run sortScores.ipynb
# %run sheetsAPI.ipynb
# %run exportStats.ipynb

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')

#requests
import requests
print("dab")
# Out:
# dab
# google sheets authentication success
# dab
# dab

# %%
#Get input
tourney_name = input("Name of tournament? ")

is_team_tourney = input("Is this a team tournament? (y/n) ")
is_team_tourney = True if is_team_tourney == 'y' else False

team_size = 0
if is_team_tourney == True:
    team_size = int(input("Team size? "))

#winning condition: score = 0, accuracy = 1, combo = 2, score v2 = 3
desired_scoring_type = input("What scoring? \
    (0)score, (1)acc, (2)combo, (3)scorev2" )
desired_scoring_type = str(desired_scoring_type)

#stage want to analyze
stage = input("What stage? ")

all_maps = readMaps('./Starter Sheets/Maps3.xlsx') #df of the maps and their mod in each stage
mp_ids = readMPLinks('./Starter Sheets/MPids.xlsx') #df of the mps in each stage
# Out:
# Name of tournament? OMF 2
# Is this a team tournament? (y/n) y
# Team size? 2
# What scoring?     (0)score, (1)acc, (2)combo, (3)scorev23
# What stage? Group Stage

# %%
start_time = time.time()

#read teams sheet if is team tournament
teams = 0
teamsInfo = {}
if is_team_tourney == True:
    teams = readTeams('./Starter Sheets/Teams.xlsx')

    
#labels = list(all_maps)
#stages = labels[0::2] #stages in the tournament
#stage_idx = 0



#---Process the desired stage of the tournament---
maps_in_stage_df = all_maps.loc[:, stage:stage + " Mods"] #df of map_ids and mod
map_ids_in_stage = maps_in_stage_df.iloc[:, 0].tolist()
map_ids_in_stage = [map_id for map_id in map_ids_in_stage if map_id != '-1']
map_mods_in_stage = maps_in_stage_df.iloc[:, 1].tolist()
map_mods_in_stage = [mod for mod in map_mods_in_stage if mod != '-1']

mp_ids_in_stage = mp_ids[stage] #list of mp_ids in stage

mods_for_each_map = dict(zip(map_ids_in_stage, \
                            map_mods_in_stage)) #track the mod each map uses
maps_info = {} #track how many times each map was picked, object count, and name
for map_id in map_ids_in_stage:
    maps_info[map_id] = {} 
    maps_info[map_id]['picked'] = 0
    
    get_scores_response = get_scores(map_id, '0', '1')
    map_total_objects = int(get_scores_response[0]['count300']) + \
                        int(get_scores_response[0]['count100']) + \
                        int(get_scores_response[0]['count50']) + \
                        int(get_scores_response[0]['countmiss'])
    maps_info[map_id]['obj count'] = map_total_objects

#Create empty leaderboards for all the maps in a stage and append to 
#all_leaderboards
leaderboards_in_stage = {} #dict of map_ids each having a leaderboard
for map_id in map_ids_in_stage:
    if map_id == '0': #@TODO why are there still '0's?
        continue
    leaderboards_in_stage[map_id] = createLeaderboard(map_id, is_team_tourney)

#Parse each match in this stage. On each match we: append to appropriate
#leaderboard, update teaminfo, update map_count dict
userId_to_username = {} #store usernames in here to reduce osu api calls
for mp_id in mp_ids_in_stage:
    #@TODO: add team_info functionality
    processMP(mp_id, leaderboards_in_stage, maps_info, 
              is_team_tourney, teams, desired_scoring_type, 
              mods_for_each_map, userId_to_username)  

#---Sort the leaderboards by score---


#stage_idx += 2

print("done-----------------------------------------------------------------")
print("--- %s seconds ---" % (time.time() - start_time))

#Construct the 'Overview', 'Best Plays', and 'Teams Overview' pages
# Out:
#      3rd err
#      3rd err
#      3rd err
#      3rd err
#      3rd err
#      3rd err
#      2nd err
#      2nd err
#      2nd err
#      2nd err
#      2nd err
#      2nd err
#      2nd err
#      2nd err
#      3rd err
#      1st err: 3 45433386
#      3rd err
#      3rd err
#      3rd err
#      3rd err
# done-----------------------------------------------------------------
# --- 75.88577103614807 seconds ---

# %%
#populate maps_info with more info for header
for map_id in maps_info:
    get_beatmaps_response = get_beatmaps(map_id)
    
    #---song's text info---
    #name
    maps_info[map_id]['name'] = get_beatmaps_response[0]['title']
    
    #artist
    maps_info[map_id]['artist'] = get_beatmaps_response[0]['artist']
    
    #creator
    maps_info[map_id]['creator'] = get_beatmaps_response[0]['creator']
   
    #difficulty name
    maps_info[map_id]['diff name'] = get_beatmaps_response[0]['version']
    
    #thumbnail
    map_url = mineThumbnail("https://old.ppy.sh/b/" + map_id)
    maps_info[map_id]['img'] = map_url
    
    #mod
    maps_info[map_id]['mod'] = mods_for_each_map[map_id]
    
    #---song stats---
    #length
    raw_length = int(get_beatmaps_response[0]['total_length'])
    mins = str(round(raw_length / 60))
    secs = raw_length % 60
    if secs < 10:
        secs = '0' + str(secs)
    else:
        secs = str(secs)
    length = mins + ':' + secs
    maps_info[map_id]['length'] = length
    
    #bpm
    maps_info[map_id]['bpm'] = round(float(get_beatmaps_response[0]['bpm']), 0)
    
    #SR
    maps_info[map_id]['sr'] = round(float(get_beatmaps_response[0]['difficultyrating']), 2)
    
    #CS
    maps_info[map_id]['cs'] = float(get_beatmaps_response[0]['diff_size'])
    
    #HP
    maps_info[map_id]['hp'] = float(get_beatmaps_response[0]['diff_drain'])
    
    #OD
    maps_info[map_id]['od'] = float(get_beatmaps_response[0]['diff_overall'])
    
    #AR
    maps_info[map_id]['ar'] = float(get_beatmaps_response[0]['diff_approach'])
    
maps_info
# Out:
# {'30485': {'picked': 7,
#   'obj count': 455,
#   'name': 'ZETSUBOU',
#   'artist': 'AN CAFE',
#   'creator': 'HarryOrunitia',
#   'diff name': 'Insane',
#   'img': '//b.ppy.sh/thumb/6863l.jpg',
#   'mod': '0',
#   'length': '3:06',
#   'bpm': 201.0,
#   'sr': 3.88,
#   'cs': 5.0,
#   'hp': 7.0,
#   'od': 7.0,
#   'ar': 7.0},
#  '42273': {'picked': 15,
#   'obj count': 731,
#   'name': 'Parallel Days',
#   'artist': 'Hirano Aya',
#   'creator': 'Sushi971',
#   'diff name': 'StrawberryStyle',
#   'img': '//b.ppy.sh/thumb/10933l.jpg',
#   'mod': '0',
#   'length': '4:07',
#   'bpm': 176.0,
#   'sr': 4.01,
#   'cs': 5.0,
#   'hp': 6.0,
#   'od': 8.0,
#   'ar': 8.0},
#  '124701': {'picked': 36,
#   'obj count': 453,
#   'name': 'Kuusou Mesorogiwi',
#   'artist': 'Yousei Teikoku',
#   'creator': 'osuplayer111',
#   'diff name': 'Insane',
#   'img': '//b.ppy.sh/thumb/39031l.jpg',
#   'mod': '0',
#   'length': '3:36',
#   'bpm': 230.0,
#   'sr': 4.15,
#   'cs': 4.0,
#   'hp': 8.0,
#   'od': 7.0,
#   'ar': 9.0},
#  '65019': {'picked': 21,
#   'obj count': 593,
#   'name': 'Absolute Demolition',
#   'artist': "SYNC.ART'S feat. Kaori Aihara",
#   'creator': 'Kecco',
#   'diff name': 'Lunatic',
#   'img': '//b.ppy.sh/thumb/18242l.jpg',
#   'mod': '0',
#   'length': '4:49',
#   'bpm': 180.0,
#   'sr': 4.15,
#   'cs': 4.0,
#   'hp': 8.0,
#   'od': 8.0,
#   'ar': 8.0},
#  '73514': {'picked': 19,
#   'obj count': 543,
#   'name': 'Orange Diz',
#   'artist': 'Yellow Zebra',
#   'creator': 'Frill',
#   'diff name': "gow's Insane",
#   'img': '//b.ppy.sh/thumb/17306l.jpg',
#   'mod': '8',
#   'length': '3:07',
#   'bpm': 147.0,
#   'sr': 4.02,
#   'cs': 4.0,
#   'hp': 5.0,
#   'od': 7.0,
#   'ar': 7.0},
#  '119803': {'picked': 22,
#   'obj count': 569,
#   'name': 'Senbonzakura (Short Ver.)',
#   'artist': 'Hatsune Miku',
#   'creator': 'NatsumeRin',
#   'diff name': 'Rin',
#   'img': '//b.ppy.sh/thumb/36858l.jpg',
#   'mod': '8',
#   'length': '3:32',
#   'bpm': 154.0,
#   'sr': 4.14,
#   'cs': 4.0,
#   'hp': 6.0,
#   'od': 8.0,
#   'ar': 8.0},
#  '54231': {'picked': 27,
#   'obj count': 342,
#   'name': 'Daisuke',
#   'artist': 'Y&Co.',
#   'creator': 'Gabi',
#   'diff name': 'Hyper',
#   'img': '//b.ppy.sh/thumb/14774l.jpg',
#   'mod': '16',
#   'length': '2:04',
#   'bpm': 157.0,
#   'sr': 3.95,
#   'cs': 4.0,
#   'hp': 6.0,
#   'od': 7.0,
#   'ar': 7.0},
#  '38581': {'picked': 30,
#   'obj count': 470,
#   'name': 'Environmental Superman Ecogainder',
#   'artist': 'Endo Masaaki',
#   'creator': 'miccoliasms',
#   'diff name': 'Recycle',
#   'img': '//b.ppy.sh/thumb/9601l.jpg',
#   'mod': '16',
#   'length': '3:06',
#   'bpm': 180.0,
#   'sr': 3.43,
#   'cs': 5.0,
#   'hp': 5.0,
#   'od': 6.0,
#   'ar': 6.0},
#  '3671': {'picked': 31,
#   'obj count': 364,
#   'name': 'Tetris',
#   'artist': '2pm',
#   'creator': 'Bonesnake',
#   'diff name': 'Level 12 (hard)',
#   'img': '//b.ppy.sh/thumb/633l.jpg',
#   'mod': '64',
#   'length': '3:58',
#   'bpm': 140.0,
#   'sr': 2.7,
#   'cs': 5.0,
#   'hp': 5.0,
#   'od': 6.0,
#   'ar': 6.0},
#  '27849': {'picked': 21,
#   'obj count': 452,
#   'name': 'All About Us (Single Version)',
#   'artist': 'TATU',
#   'creator': 'osuplayer111',
#   'diff name': 'oSuPlaYeR mIX',
#   'img': '//b.ppy.sh/thumb/5886l.jpg',
#   'mod': '64',
#   'length': '3:55',
#   'bpm': 162.0,
#   'sr': 2.83,
#   'cs': 5.0,
#   'hp': 7.0,
#   'od': 7.0,
#   'ar': 7.0},
#  '1562': {'picked': 34,
#   'obj count': 629,
#   'name': 'agony',
#   'artist': 'KOTOKO',
#   'creator': 'K-S-O',
#   'diff name': 'Insane',
#   'img': '//b.ppy.sh/thumb/302l.jpg',
#   'mod': '2',
#   'length': '4:36',
#   'bpm': 132.0,
#   'sr': 3.64,
#   'cs': 7.0,
#   'hp': 8.0,
#   'od': 8.0,
#   'ar': 8.0},
#  '34077': {'picked': 24,
#   'obj count': 364,
#   'name': 'CARTOON HEROES (Speedy Mix)',
#   'artist': 'Barbie Young',
#   'creator': 'Skyripper',
#   'diff name': 'Heavy',
#   'img': '//b.ppy.sh/thumb/8245l.jpg',
#   'mod': '1024',
#   'length': '1:27',
#   'bpm': 170.0,
#   'sr': 3.25,
#   'cs': 5.0,
#   'hp': 7.0,
#   'od': 7.0,
#   'ar': 7.0},
#  '113592': {'picked': 13,
#   'obj count': 928,
#   'name': 'Boku no Sainou -dub mix-',
#   'artist': 'toku feat. Pagoda',
#   'creator': 'Garven',
#   'diff name': 'Collab',
#   'img': '//b.ppy.sh/thumb/33914l.jpg',
#   'mod': '0',
#   'length': '6:09',
#   'bpm': 190.0,
#   'sr': 4.2,
#   'cs': 4.0,
#   'hp': 6.0,
#   'od': 7.0,
#   'ar': 8.0}}

# %%
#create the google spreadsheet containing all the leaderboards for stage
body = {
    "properties": {
        "title": tourney_name + ' ' + stage + ' Leaderboards'
    },
    "sheets": []
}
for map_id in maps_info:
    body['sheets'].append({
        "properties":{
            "title": maps_info[map_id]['name']
        }
    })
request = service.spreadsheets().create(body=body)
response = request.execute()
print(response)

leaderboard_spreadsheetId = response['spreadsheetId']
# Out:
# {'spreadsheetId': '1QjPnZKI-g5bLu5zry-n8FTKILudVHyoysck0SF9bsMU', 'properties': {'title': 'OMF 2 Group Stage Leaderboards', 'locale': 'en_US', 'autoRecalc': 'ON_CHANGE', 'timeZone': 'Etc/GMT', 'defaultFormat': {'backgroundColor': {'red': 1, 'green': 1, 'blue': 1}, 'padding': {'top': 2, 'right': 3, 'bottom': 2, 'left': 3}, 'verticalAlignment': 'BOTTOM', 'wrapStrategy': 'OVERFLOW_CELL', 'textFormat': {'foregroundColor': {}, 'fontFamily': 'arial,sans,sans-serif', 'fontSize': 10, 'bold': False, 'italic': False, 'strikethrough': False, 'underline': False}}}, 'sheets': [{'properties': {'sheetId': 1975759681, 'title': 'ZETSUBOU', 'index': 0, 'sheetType': 'GRID', 'gridProperties': {'rowCount': 1000, 'columnCount': 26}}}, {'properties': {'sheetId': 429348597, 'title': 'Parallel Days', 'index': 1, 'sheetType': 'GRID', 'gridProperties': {'rowCount': 1000, 'columnCount': 26}}}, {'properties': {'sheetId': 1754479990, 'title': 'Kuusou Mesorogiwi', 'index': 2, 'sheetType': 'GRID', 'gridProperties': {'rowCount': 1000, 'columnCount': 26}}}, {'properties': {'sheetId': 433466652, 'title': 'Absolute Demolition', 'index': 3, 'sheetType': 'GRID', 'gridProperties': {'rowCount': 1000, 'columnCount': 26}}}, {'properties': {'sheetId': 444810686, 'title': 'Orange Diz', 'index': 4, 'sheetType': 'GRID', 'gridProperties': {'rowCount': 1000, 'columnCount': 26}}}, {'properties': {'sheetId': 2002254577, 'title': 'Senbonzakura (Short Ver.)', 'index': 5, 'sheetType': 'GRID', 'gridProperties': {'rowCount': 1000, 'columnCount': 26}}}, {'properties': {'sheetId': 443193235, 'title': 'Daisuke', 'index': 6, 'sheetType': 'GRID', 'gridProperties': {'rowCount': 1000, 'columnCount': 26}}}, {'properties': {'sheetId': 2049406704, 'title': 'Environmental Superman Ecogainder', 'index': 7, 'sheetType': 'GRID', 'gridProperties': {'rowCount': 1000, 'columnCount': 26}}}, {'properties': {'sheetId': 1355264166, 'title': 'Tetris', 'index': 8, 'sheetType': 'GRID', 'gridProperties': {'rowCount': 1000, 'columnCount': 26}}}, {'properties': {'sheetId': 641436298, 'title': 'All About Us (Single Version)', 'index': 9, 'sheetType': 'GRID', 'gridProperties': {'rowCount': 1000, 'columnCount': 26}}}, {'properties': {'sheetId': 1326034102, 'title': 'agony', 'index': 10, 'sheetType': 'GRID', 'gridProperties': {'rowCount': 1000, 'columnCount': 26}}}, {'properties': {'sheetId': 5311411, 'title': 'CARTOON HEROES (Speedy Mix)', 'index': 11, 'sheetType': 'GRID', 'gridProperties': {'rowCount': 1000, 'columnCount': 26}}}, {'properties': {'sheetId': 852710296, 'title': 'Boku no Sainou -dub mix-', 'index': 12, 'sheetType': 'GRID', 'gridProperties': {'rowCount': 1000, 'columnCount': 26}}}], 'spreadsheetUrl': 'https://docs.google.com/a/ucsd.edu/spreadsheets/d/1QjPnZKI-g5bLu5zry-n8FTKILudVHyoysck0SF9bsMU/edit'}

# %%
#---Populate the new sheet with the leaderboards---
for map_id in leaderboards_in_stage:
    
    #---append the stuff maps_info---
    range_ = maps_info[map_id]['name'] + '!A1'
    
    
    #---append the leaderboard headers---
    range_ = maps_info[map_id]['name'] + '!A6'
    input_ = {
        "values": [
            leaderboards_in_stage[map_id]['scores'].columns.tolist()
        ]
    }
    request = service.spreadsheets().values().update(
        spreadsheetId = leaderboard_spreadsheetId, 
        range = range_,
        valueInputOption = 'USER_ENTERED',
        body = input_
    )
    response = request.execute()
    
    #---append the leaderboard---
    range_ = maps_info[map_id]['name'] + '!A7'
    scores = sortScores(leaderboards_in_stage[map_id]['scores'])
    input_ = {
        "values": scores.values.tolist()
    }
    request = service.spreadsheets().values().update(
        spreadsheetId = leaderboard_spreadsheetId, 
        range = range_,
        valueInputOption = 'USER_ENTERED',
        body = input_
    )
    response = request.execute()
    pprint(response)
# Out:
# {'spreadsheetId': '13o2LKyepKZyaGBIK0XNrwxAr_P-xwDQrUX3UUwtd1dg',
#  'updatedCells': 252,
#  'updatedColumns': 9,
#  'updatedRange': 'ZETSUBOU!A2:I29',
#  'updatedRows': 28}
# {'spreadsheetId': '13o2LKyepKZyaGBIK0XNrwxAr_P-xwDQrUX3UUwtd1dg',
#  'updatedCells': 549,
#  'updatedColumns': 9,
#  'updatedRange': "'Parallel Days'!A2:I62",
#  'updatedRows': 61}
# {'spreadsheetId': '13o2LKyepKZyaGBIK0XNrwxAr_P-xwDQrUX3UUwtd1dg',
#  'updatedCells': 1233,
#  'updatedColumns': 9,
#  'updatedRange': "'Kuusou Mesorogiwi'!A2:I138",
#  'updatedRows': 137}
# {'spreadsheetId': '13o2LKyepKZyaGBIK0XNrwxAr_P-xwDQrUX3UUwtd1dg',
#  'updatedCells': 702,
#  'updatedColumns': 9,
#  'updatedRange': "'Absolute Demolition'!A2:I79",
#  'updatedRows': 78}
# {'spreadsheetId': '13o2LKyepKZyaGBIK0XNrwxAr_P-xwDQrUX3UUwtd1dg',
#  'updatedCells': 675,
#  'updatedColumns': 9,
#  'updatedRange': "'Orange Diz'!A2:I76",
#  'updatedRows': 75}
# {'spreadsheetId': '13o2LKyepKZyaGBIK0XNrwxAr_P-xwDQrUX3UUwtd1dg',
#  'updatedCells': 783,
#  'updatedColumns': 9,
#  'updatedRange': "'Senbonzakura (Short Ver.)'!A2:I88",
#  'updatedRows': 87}
# {'spreadsheetId': '13o2LKyepKZyaGBIK0XNrwxAr_P-xwDQrUX3UUwtd1dg',
#  'updatedCells': 954,
#  'updatedColumns': 9,
#  'updatedRange': 'Daisuke!A2:I107',
#  'updatedRows': 106}
# {'spreadsheetId': '13o2LKyepKZyaGBIK0XNrwxAr_P-xwDQrUX3UUwtd1dg',
#  'updatedCells': 1035,
#  'updatedColumns': 9,
#  'updatedRange': "'Environmental Superman Ecogainder'!A2:I116",
#  'updatedRows': 115}
# {'spreadsheetId': '13o2LKyepKZyaGBIK0XNrwxAr_P-xwDQrUX3UUwtd1dg',
#  'updatedCells': 1089,
#  'updatedColumns': 9,
#  'updatedRange': 'Tetris!A2:I122',
#  'updatedRows': 121}
# {'spreadsheetId': '13o2LKyepKZyaGBIK0XNrwxAr_P-xwDQrUX3UUwtd1dg',
#  'updatedCells': 738,
#  'updatedColumns': 9,
#  'updatedRange': "'All About Us (Single Version)'!A2:I83",
#  'updatedRows': 82}
# {'spreadsheetId': '13o2LKyepKZyaGBIK0XNrwxAr_P-xwDQrUX3UUwtd1dg',
#  'updatedCells': 1197,
#  'updatedColumns': 9,
#  'updatedRange': 'agony!A2:I134',
#  'updatedRows': 133}
# {'spreadsheetId': '13o2LKyepKZyaGBIK0XNrwxAr_P-xwDQrUX3UUwtd1dg',
#  'updatedCells': 864,
#  'updatedColumns': 9,
#  'updatedRange': "'CARTOON HEROES (Speedy Mix)'!A2:I97",
#  'updatedRows': 96}
# {'spreadsheetId': '13o2LKyepKZyaGBIK0XNrwxAr_P-xwDQrUX3UUwtd1dg',
#  'updatedCells': 477,
#  'updatedColumns': 9,
#  'updatedRange': "'Boku no Sainou -dub mix-'!A2:I54",
#  'updatedRows': 53}

# %%
#testing appending the 6line header
#---Populate the new sheet with the leaderboards---
for map_id in leaderboards_in_stage:
    
    #---append the logistics of maps_info---
    range_ = maps_info[map_id]['name'] + '!A1'
    input_ = {
        "values": [
            #row 1
            [
                "=IMAGE(\"https:%s\")" % maps_info[map_id]['img'],
                "",
                "Title",
                "",
                "Artist",
            ],
            #row 2
            [
                "", "",
                "%s" % maps_info[map_id]['name'],
                "",
                #NVM just make a table then update
            ]
            
        ]
    }
    request = service.spreadsheets().values().update(
        spreadsheetId = leaderboard_spreadsheetId, 
        range = range_,
        valueInputOption = 'USER_ENTERED',
        body = input_
    )
    response = request.execute()
    
    #pprint(response)

# %%
get_beatmaps_response = get_beatmaps("252002")
raw_length = int(get_beatmaps_response[0]['total_length'])
mins = round(raw_length / 60)
secs = raw_length % 60
length = str(mins) + ':' + str(secs)
length
# Out:
# '2:26'

# %%
scores.values.tolist()
# Out:
# [['=ROW() - 6',
#   'TheShadowOfDark',
#   'Here for #1s',
#   'S',
#   1073779,
#   1398,
#   0.9957,
#   '',
#   'https://osu.ppy.sh/community/matches/45442499'],
#  ['=ROW() - 6',
#   'Entry',
#   'Bulamadım',
#   'S',
#   1001259,
#   1397,
#   0.9964,
#   '',
#   'https://osu.ppy.sh/community/matches/45187464'],
#  ['=ROW() - 6',
#   'Luminiscental',
#   'Baguetteophobia',
#   'S',
#   983399,
#   1397,
#   0.9907,
#   '',
#   'https://osu.ppy.sh/community/matches/45446028'],
#  ['=ROW() - 6',
#   'Epicmouse',
#   'what is dis',
#   'S',
#   962763,
#   1398,
#   0.9835,
#   '',
#   'https://osu.ppy.sh/community/matches/45190620'],
#  ['=ROW() - 6',
#   'Malson',
#   '',
#   'S',
#   950256,
#   1398,
#   0.9779,
#   '',
#   'https://osu.ppy.sh/community/matches/45395828'],
#  ['=ROW() - 6',
#   'Eliteronix',
#   'egagegsgaggagaha',
#   'A',
#   812232,
#   1224,
#   0.986,
#   '',
#   'https://osu.ppy.sh/community/matches/45411050'],
#  ['=ROW() - 6',
#   'Eliteronix',
#   'egagegsgaggagaha',
#   'A',
#   812232,
#   1224,
#   0.986,
#   '',
#   'https://osu.ppy.sh/community/matches/45411050'],
#  ['=ROW() - 6',
#   'Shigerd',
#   '¿Comeback?',
#   'A',
#   792577,
#   1192,
#   0.9842,
#   '',
#   'https://osu.ppy.sh/community/matches/45446028'],
#  ['=ROW() - 6',
#   'AitorAmu',
#   'egagegsgaggagaha',
#   'A',
#   771981,
#   1189,
#   0.9434,
#   '',
#   'https://osu.ppy.sh/community/matches/45411050'],
#  ['=ROW() - 6',
#   'AitorAmu',
#   'egagegsgaggagaha',
#   'A',
#   771981,
#   1189,
#   0.9434,
#   '',
#   'https://osu.ppy.sh/community/matches/45411050'],
#  ['=ROW() - 6',
#   '[Lucky]',
#   '',
#   'A',
#   736212,
#   1069,
#   0.9925,
#   '',
#   'https://osu.ppy.sh/community/matches/45190620'],
#  ['=ROW() - 6',
#   'Franleon86',
#   "The Choke Brother's",
#   'S',
#   709054,
#   991,
#   0.9711,
#   '',
#   'https://osu.ppy.sh/community/matches/45218842'],
#  ['=ROW() - 6',
#   'PurpleSatanWeed',
#   'what is dis',
#   'A',
#   692403,
#   994,
#   0.9923,
#   '',
#   'https://osu.ppy.sh/community/matches/45190620'],
#  ['=ROW() - 6',
#   'Shaper',
#   '',
#   'S',
#   672718,
#   956,
#   0.9828,
#   '',
#   'https://osu.ppy.sh/community/matches/45442499'],
#  ['=ROW() - 6',
#   '-Nao Tomori-',
#   'Galer',
#   'S',
#   671622,
#   969,
#   0.9788,
#   '',
#   'https://osu.ppy.sh/community/matches/45190078'],
#  ['=ROW() - 6',
#   'DwarfSpykerr',
#   'Cute Anime Girls',
#   'S',
#   668218,
#   946,
#   0.9838,
#   '',
#   'https://osu.ppy.sh/community/matches/45190078'],
#  ['=ROW() - 6',
#   'Just Lucan',
#   'Pie in the Sky',
#   'A',
#   654834,
#   768,
#   0.9917,
#   '',
#   'https://osu.ppy.sh/community/matches/45190620'],
#  ['=ROW() - 6',
#   'qweersfds',
#   "Lown'tAR",
#   'A',
#   647979,
#   975,
#   0.9777,
#   '',
#   'https://osu.ppy.sh/community/matches/45395828'],
#  ['=ROW() - 6',
#   'sentez',
#   'Bulamadım',
#   'A',
#   631337,
#   829,
#   0.9817,
#   '',
#   'https://osu.ppy.sh/community/matches/45187464'],
#  ['=ROW() - 6',
#   'Wutever',
#   'Team Aesthetic Reborn',
#   'A',
#   614091,
#   759,
#   0.9864,
#   '',
#   'https://osu.ppy.sh/community/matches/45442499'],
#  ['=ROW() - 6',
#   '- James -',
#   '¿Comeback?',
#   'A',
#   601969,
#   941,
#   0.9691,
#   '',
#   'https://osu.ppy.sh/community/matches/45446028'],
#  ['=ROW() - 6',
#   'Sliceofpie',
#   'Kyroh',
#   'A',
#   583299,
#   762,
#   0.9783,
#   '',
#   'https://osu.ppy.sh/community/matches/45411050'],
#  ['=ROW() - 6',
#   'Sliceofpie',
#   'Kyroh',
#   'A',
#   583299,
#   762,
#   0.9783,
#   '',
#   'https://osu.ppy.sh/community/matches/45411050'],
#  ['=ROW() - 6',
#   'RSA',
#   'AT Germanic',
#   'A',
#   579389,
#   814,
#   0.9639,
#   '',
#   'https://osu.ppy.sh/community/matches/45219073'],
#  ['=ROW() - 6',
#   'Baziu',
#   'Mnie to lotto',
#   'S',
#   572641,
#   905,
#   0.9731,
#   '',
#   'https://osu.ppy.sh/community/matches/45218842'],
#  ['=ROW() - 6',
#   'Nibareaux',
#   'Lobby 42',
#   'A',
#   572508,
#   879,
#   0.9603,
#   '',
#   'https://osu.ppy.sh/community/matches/45225175'],
#  ['=ROW() - 6',
#   'Mr kamfret',
#   'Galer',
#   'A',
#   548207,
#   870,
#   0.9698,
#   '',
#   'https://osu.ppy.sh/community/matches/45187464'],
#  ['=ROW() - 6',
#   'Vararaup',
#   'Kyroh',
#   'A',
#   535334,
#   748,
#   0.9688,
#   '',
#   'https://osu.ppy.sh/community/matches/45411050'],
#  ['=ROW() - 6',
#   'Vararaup',
#   'Kyroh',
#   'A',
#   535334,
#   748,
#   0.9688,
#   '',
#   'https://osu.ppy.sh/community/matches/45411050'],
#  ['=ROW() - 6',
#   'Mr kamfret',
#   'Galer',
#   'A',
#   528404,
#   678,
#   0.9774,
#   '',
#   'https://osu.ppy.sh/community/matches/45190078'],
#  ['=ROW() - 6',
#   'piwkotyskie',
#   'NicoNicoNiii',
#   'A',
#   527352,
#   780,
#   0.9802,
#   '',
#   'https://osu.ppy.sh/community/matches/45225175'],
#  ['=ROW() - 6',
#   'qweersfds',
#   "Lown'tAR",
#   'A',
#   475969,
#   709,
#   0.967,
#   '',
#   'https://osu.ppy.sh/community/matches/45219073'],
#  ['=ROW() - 6',
#   'xHei_57',
#   'Cute Anime Girls',
#   'A',
#   471141,
#   576,
#   0.9765,
#   '',
#   'https://osu.ppy.sh/community/matches/45190078'],
#  ['=ROW() - 6',
#   'TLQ_Yoshii',
#   'Baguetteophobia',
#   'A',
#   463214,
#   567,
#   0.9806,
#   '',
#   'https://osu.ppy.sh/community/matches/45446028'],
#  ['=ROW() - 6',
#   'Nightlys',
#   'Team Aesthetic Reborn',
#   'A',
#   410074,
#   538,
#   0.9671,
#   '',
#   'https://osu.ppy.sh/community/matches/45442499'],
#  ['=ROW() - 6',
#   'Sandbagger',
#   '',
#   'B',
#   409114,
#   589,
#   0.9287,
#   '',
#   'https://osu.ppy.sh/community/matches/45218842'],
#  ['=ROW() - 6',
#   'Raoul',
#   '',
#   'A',
#   400505,
#   555,
#   0.9438,
#   '',
#   'https://osu.ppy.sh/community/matches/45442499'],
#  ['=ROW() - 6',
#   'NoVaLian',
#   'Galer',
#   'A',
#   392453,
#   580,
#   0.9416,
#   '',
#   'https://osu.ppy.sh/community/matches/45187464'],
#  ['=ROW() - 6',
#   'irgendetwas',
#   'AT Germanic',
#   'A',
#   365503,
#   566,
#   0.9452,
#   '',
#   'https://osu.ppy.sh/community/matches/45219073'],
#  ['=ROW() - 6',
#   'Flow-',
#   'PhantomHive',
#   'B',
#   353774,
#   559,
#   0.8951,
#   '',
#   'https://osu.ppy.sh/community/matches/45398685'],
#  ['=ROW() - 6',
#   'Triojo',
#   'Avrelove',
#   'B',
#   346866,
#   553,
#   0.9255,
#   '',
#   'https://osu.ppy.sh/community/matches/45395828'],
#  ['=ROW() - 6',
#   'AFKBRB',
#   '',
#   'B',
#   341507,
#   771,
#   0.894,
#   '',
#   'https://osu.ppy.sh/community/matches/45398685'],
#  ['=ROW() - 6',
#   'Akakuro',
#   "The Choke Brother's",
#   'B',
#   334837,
#   482,
#   0.9134,
#   '',
#   'https://osu.ppy.sh/community/matches/45218842'],
#  ['=ROW() - 6',
#   'Shovan',
#   'Lobby 42',
#   'A',
#   326640,
#   226,
#   0.9596,
#   '',
#   'https://osu.ppy.sh/community/matches/45225175'],
#  ['=ROW() - 6',
#   'Rapidz',
#   "Lown'tAR",
#   'A',
#   317422,
#   427,
#   0.9388,
#   '',
#   'https://osu.ppy.sh/community/matches/45395828'],
#  ['=ROW() - 6',
#   'staddle',
#   'PhantomHive',
#   'B',
#   272062,
#   417,
#   0.8833,
#   '',
#   'https://osu.ppy.sh/community/matches/45398685'],
#  ['=ROW() - 6',
#   'emfreya',
#   'A',
#   'A',
#   255776,
#   264,
#   0.9379,
#   '',
#   'https://osu.ppy.sh/community/matches/45398685'],
#  ['=ROW() - 6',
#   'Rapidz',
#   "Lown'tAR",
#   'B',
#   209862,
#   233,
#   0.9028,
#   '',
#   'https://osu.ppy.sh/community/matches/45219073'],
#  ['=ROW() - 6',
#   'Khroma',
#   'A',
#   'C',
#   140614,
#   453,
#   0.7809,
#   '',
#   'https://osu.ppy.sh/community/matches/45197086'],
#  ['=ROW() - 6',
#   'FireAce62',
#   'A',
#   'C',
#   134673,
#   299,
#   0.7958,
#   '',
#   'https://osu.ppy.sh/community/matches/45398685'],
#  ['=ROW() - 6',
#   'my team sucks',
#   'Beefy Burrito Bois',
#   'B',
#   106582,
#   289,
#   0.8953,
#   '',
#   'https://osu.ppy.sh/community/matches/45197086'],
#  ['=ROW() - 6',
#   'Weed',
#   'what is dis',
#   'C',
#   51715,
#   337,
#   0.7771,
#   '',
#   'https://osu.ppy.sh/community/matches/45197086'],
#  ['=ROW() - 6',
#   'emfreya',
#   'A',
#   'C',
#   36232,
#   103,
#   0.7879,
#   '',
#   'https://osu.ppy.sh/community/matches/45197086']]
